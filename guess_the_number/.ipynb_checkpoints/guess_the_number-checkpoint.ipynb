# %%
import guess_the_number
# Out:
# Play the game? Type 'y' or 'n': y
#
#
#       o__ __o                                                         o       o                            o          o                                  o
#      /v     v\                                                       <|>     <|>                          <|\        <|>                                <|>
#     />       <\                                                      < >     / >                          / \o      / \                                / >
#   o/                o       o     o__  __o       __o__    __o__       |      \o__ __o      o__  __o       \o/ v\     \o/   o       o   \o__ __o__ __o   \o__ __o       o__  __o   \o__ __o
#  <|       _\__o__  <|>     <|>   /v      |>     />  \    />  \        o__/_   |     v\    /v      |>       |   <\     |   <|>     <|>   |     |     |>   |     v\     /v      |>   |     |>
# ...
